# %% [markdown]
# <a href="https://colab.research.google.com/github/Ser-Performance-DNC-Grupo-01/Desafio/blob/main/Ser_Perf_vendas_CLI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Este codigo contem todas as tabelas de vendas dos 50 Clientes.

# %%
# Upload bibliotecas
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Login google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Importando pastas do drive
import os

caminho_pasta = '/content/drive/MyDrive/Ser Perfomance/drive-download-20240718T143241Z-001'

if os.path.exists(caminho_pasta):
  print('pasta encontradas')
  pastas = [nome for nome in os.listdir(caminho_pasta) if os.path.isdir(os.path.join(caminho_pasta, nome))]
  print('pastas encontradas dentro do caminho')
  for pasta in pastas:
    print(pasta)
else:
  print(f'pasta {caminho_pasta} não existe')
# Out:
# pasta encontradas
# pastas encontradas dentro do caminho
# 00D509DB-8BE0-4ACE-A5AD-5BF37386995B
# 15EDFB01-20F8-451D-968C-3D76DA48FA5D
# 2BB774CA-42B6-4958-AEAD-BE99DBE606CC
# 3B4192CC-761D-45BA-A325-8D023FDC6D3A
# 098887C7-B9E5-4BCC-8B68-D20E94CBC297
# 27F0C275-12AC-452D-BD2D-FB2D6D6977CE
# 147229CD-F3A5-4E75-91DC-7995C01F9438
# 34F59AF1-257C-4CEA-BEB0-67911D3F179D
# 440D767E-C2C6-4344-87E0-4FDC517401A9
# 2023D051-1530-43A4-B039-7225D3A210D9
# 4FF291F2-92A7-49AF-A40E-EB76D8F18F58
# 485A81C2-65C2-4725-90A9-6AF52734DD23
# 57CEF1EC-60F0-495B-9F34-32BA075CB39F
# 4C94CE12-1188-4B0C-9122-F2BDE5CB697A
# 4A74F755-039A-4777-834D-E9D7033E9142
# 54FAF654-1B94-4860-B113-9AE4CE8F1CFD
# 4F8F5521-B308-4503-89B9-9482D8B24351
# 4903AA7A-ACE3-4C66-AD62-3FDBDD13CBF5
# 4FC32C34-7C03-4291-9325-6CA7055E7777
# 487B7C30-6569-4857-8188-3DC4F2DC266D
# 7672F3C1-00A6-42F2-A72C-8804C289CEC9
# 7257F457-ED17-4DD5-B738-0C8734A36101
# 711E5097-06EA-4F3F-BF49-DC960808C70F
# 5CD89290-B8DF-414F-9720-5891CD0BCFA5
# ...

# %%
tabelas = {}
# importar tabela das pastas
def importar_tabelas(pasta):
    for item in os.listdir(pasta):
        item_path = os.path.join(pasta, item)
        if os.path.isdir(item_path):
            importar_tabelas(item_path)  # Chamada recursiva para subpastas
        elif item.endswith('.csv'):  # Verifica se o item é um arquivo CSV
            df = pd.read_csv(item_path)  # Importa o arquivo CSV como DataFrame
            # Faça o que precisar com o DataFrame (análise, processamento, etc.)
            print(f'Conteúdo da tabela {item}:')
            print(df)
            print('\n')

# %%
# Lista com os nomes dos arquivos das 50 tabelas
arquivos = ['/content/drive/MyDrive/Ser Perfomance/drive-download-20240718T143241Z-001/00D509DB-8BE0-4ACE-A5AD-5BF37386995B/00D509DB-8BE0-4ACE-A5AD-5BF37386995B_vendas.csv',
            '/content/drive/MyDrive/Ser Perfomance/drive-download-20240718T143241Z-001/098887C7-B9E5-4BCC-8B68-D20E94CBC297/098887C7-B9E5-4BCC-8B68-D20E94CBC297_vendas.csv',
            '/content/drive/MyDrive/Ser Perfomance/drive-download-20240718T143241Z-001/147229CD-F3A5-4E75-91DC-7995C01F9438/147229CD-F3A5-4E75-91DC-7995C01F9438_vendas.csv',
            '/content/drive/MyDrive/Ser Perfomance/drive-download-20240718T143241Z-001/15EDFB01-20F8-451D-968C-3D76DA48FA5D/15EDFB01-20F8-451D-968C-3D76DA48FA5D_vendas.csv',
            '/content/drive/MyDrive/Ser Perfomance/drive-download-20240718T143241Z-001/2023D051-1530-43A4-B039-7225D3A210D9/2023D051-1530-43A4-B039-7225D3A210D9_vendas.csv',
            '/content/drive/MyDrive/Ser Perfomance/drive-download-20240718T143241Z-001/27F0C275-12AC-452D-BD2D-FB2D6D6977CE/27F0C275-12AC-452D-BD2D-FB2D6D6977CE_vendas.csv',
            '/content/drive/MyDrive/Ser Perfomance/drive-download-20240718T143241Z-001/2BB774CA-42B6-4958-AEAD-BE99DBE606CC/2BB774CA-42B6-4958-AEAD-BE99DBE606CC_vendas.csv',
            '/content/drive/MyDrive/Ser Perfomance/drive-download-20240718T143241Z-001
vendas.csv',
            '/content/drive/MyDrive/Ser Perfomance/drive-download-20240718T143241Z-001/AEF86F4A-05EA-417B-A6B8-E0D75A8C12B0/AEF86F4A-05EA-417B-A6B8-E0D75A8C12B0_vendas.csv',
            '/content/drive/MyDrive/Ser Perfomance/drive-download-20240718T143241Z-001/B75171F8-9C93-4A68-9EA4-8CD8348D6293/B75171F8-9C93-4A68-9EA4-8CD8348D6293_vendas.csv',
            '/content/drive/MyDrive/Ser Perfomance/drive-download-20240718T143241Z-001/BAC1F505-2A82-41BD-8DD9-01205676EA3E/BAC1F505-2A82-41BD-8DD9-01205676EA3E_vendas.csv',
            '/content/drive/MyDrive/Ser Perfomance/drive-download-20240718T143241Z-001/CFA413B7-7821-497B-A322-542A4176E65D/CFA413B7-7821-497B-A322-542A4176E65D_vendas.csv',
            '/content/drive/MyDrive/Ser Perfomance/drive-download-20240718T143241Z-001/D4F1A92F-5552-46AA-BE5C-B45C37E66C4E/D4F1A92F-5552-46AA-BE5C-B45C37E66C4E_vendas.csv',
            '/content/drive/MyDrive/Ser Perfomance/drive-download-20240718T143241Z-001/D5B9D44C-D644-4207-8F98-02A18EC73B86/D5B9D44C-D644-4207-8F98-02A18EC73B86_vendas.csv',
            '/content/drive/MyDrive/Ser Perfomance/drive-download-20240718T143241Z-001/D749F2B0-AE4D-4969-9407-A5970AFD80BB/D749F2B0-AE4D-4969-9407-A5970AFD80BB_vendas.csv',
            '/content/drive/MyDrive/Ser Perfomance/drive-download-20240718T143241Z-001/D9C754A8-23E2-4977-A2E1-A52154414F02/D9C754A8-23E2-4977-A2E1-A52154414F02_vendas.csv',
            '/content/drive/MyDrive/Ser Perfomance/drive-download-20240718T143241Z-001/DCA51EA9-F37D-49A3-B209-46B0BE5346B0/DCA51EA9-F37D-49A3-B209-46B0BE5346B0_vendas.csv',
            '/content/drive/MyDrive/Ser Perfomance/drive-download-20240718T143241Z-001/DF055A14-4E69-497A-88C7-1D9BAC39B672/DF055A14-4E69-497A-88C7-1D9BAC39B672_vendas.csv',
            '/content/drive/MyDrive/Ser Perfomance/drive-download-20240718T143241Z-001/E2017589-BBF0-48A3-81A0-73ED84D0F993/E2017589-BBF0-48A3-81A0-73ED84D0F993_vendas.csv',
            '/content/drive/MyDrive/Ser Perfomance/drive-download-20240718T143241Z-001/E504E63C-326C-4CB7-A9BE-704EE6C677F3/E504E63C-326C-4CB7-A9BE-704EE6C677F3_vendas.csv',
            '/content/drive/MyDrive/Ser Perfomance/drive-download-20240718T143241Z-001/EC9FD97E-32D9-43D3-8C25-15FD075D9750/EC9FD97E-32D9-43D3-8C25-15FD075D9750_vendas.csv']

# lista para armazenar os DataFrames de cada tabela
tabelas = []

# Loop para carregar e analisar cada tabela
for arquivo in arquivos:
    # Carregar a tabela
    df = pd.read_csv(arquivo)
    tabelas.append(df)
# Combinar todos os DataFrames em um único DataFrame
resultado_final = pd.concat(tabelas)
# Exibir o resultado final combinado
print(resultado_final)
# Out:
#             Data                           Funcionario  \
# 0     2023-06-02  8EB10BCB-42E7-42EF-AF88-07BE7BA740C3
# 1     2023-06-03  8EB10BCB-42E7-42EF-AF88-07BE7BA740C3
# 2     2023-06-05  8EB10BCB-42E7-42EF-AF88-07BE7BA740C3
# 3     2023-06-06  8EB10BCB-42E7-42EF-AF88-07BE7BA740C3
# 4     2023-06-07  8EB10BCB-42E7-42EF-AF88-07BE7BA740C3
# ...          ...                                   ...
# 1491  2024-04-01  97873ADF-2A4B-4A1B-9CDB-F1E683912BE2
# 1492  2024-04-03  97873ADF-2A4B-4A1B-9CDB-F1E683912BE2
# 1493  2024-04-17  97873ADF-2A4B-4A1B-9CDB-F1E683912BE2
# 1494  2024-04-19  97873ADF-2A4B-4A1B-9CDB-F1E683912BE2
# 1495  2024-04-25  97873ADF-2A4B-4A1B-9CDB-F1E683912BE2
#
#                                    Unidade  N_Boletos  N_Produtos  Vlr_Bruto  \
# 0     FE9FCF8B-590E-4C08-B6F5-20B0A6CCF8E6          1        1.00     165.00
# 1     FE9FCF8B-590E-4C08-B6F5-20B0A6CCF8E6          1        1.00     915.00
# ...

# %%
df_vendas = resultado_final
df_vendas.shape
# Out:
# (2116527, 9)

# %%
df_vendas.head()
# Out:
#          Data                           Funcionario  \
# 0  2023-06-02  8EB10BCB-42E7-42EF-AF88-07BE7BA740C3
# 1  2023-06-03  8EB10BCB-42E7-42EF-AF88-07BE7BA740C3
# 2  2023-06-05  8EB10BCB-42E7-42EF-AF88-07BE7BA740C3
# 3  2023-06-06  8EB10BCB-42E7-42EF-AF88-07BE7BA740C3
# 4  2023-06-07  8EB10BCB-42E7-42EF-AF88-07BE7BA740C3
#
#                                 Unidade  N_Boletos  N_Produtos  Vlr_Bruto  \
# 0  FE9FCF8B-590E-4C08-B6F5-20B0A6CCF8E6          1         1.0      165.0
# 1  FE9FCF8B-590E-4C08-B6F5-20B0A6CCF8E6          1         1.0      915.0
# 2  FE9FCF8B-590E-4C08-B6F5-20B0A6CCF8E6          1         1.0     1460.0
# 3  FE9FCF8B-590E-4C08-B6F5-20B0A6CCF8E6          1         4.0     6850.0
# 4  FE9FCF8B-590E-4C08-B6F5-20B0A6CCF8E6          3         6.0     6867.0
#
#    Vlr_Desconto  Vlr_Liquido                            cli_codigo
# 0           0.0        165.0  00D509DB-8BE0-4ACE-A5AD-5BF37386995B
# 1           0.0        915.0  00D509DB-8BE0-4ACE-A5AD-5BF37386995B
# ...

# %%
df_vendas.tail()
# Out:
#             Data                           Funcionario  \
# 1491  2024-04-01  97873ADF-2A4B-4A1B-9CDB-F1E683912BE2
# 1492  2024-04-03  97873ADF-2A4B-4A1B-9CDB-F1E683912BE2
# 1493  2024-04-17  97873ADF-2A4B-4A1B-9CDB-F1E683912BE2
# 1494  2024-04-19  97873ADF-2A4B-4A1B-9CDB-F1E683912BE2
# 1495  2024-04-25  97873ADF-2A4B-4A1B-9CDB-F1E683912BE2
#
#                                    Unidade  N_Boletos  N_Produtos  Vlr_Bruto  \
# 1491  DD3BDC53-716C-4254-874F-9C9CFB41CAE0          4       11.00     592.90
# 1492  DD3BDC53-716C-4254-874F-9C9CFB41CAE0          2        6.00     157.18
# 1493  DD3BDC53-716C-4254-874F-9C9CFB41CAE0          4       25.00     428.60
# 1494  DD3BDC53-716C-4254-874F-9C9CFB41CAE0          3        3.03      87.19
# 1495  DD3BDC53-716C-4254-874F-9C9CFB41CAE0          1        2.00      17.80
#
#       Vlr_Desconto  Vlr_Liquido                            cli_codigo
# 1491          0.00       592.90  EC9FD97E-32D9-43D3-8C25-15FD075D9750
# ...

# %%
df_vendas.groupby(['cli_codigo'])['N_Boletos'].sum()
# Out:
# cli_codigo
# 00D509DB-8BE0-4ACE-A5AD-5BF37386995B      53640
# 098887C7-B9E5-4BCC-8B68-D20E94CBC297    2902558
# 147229CD-F3A5-4E75-91DC-7995C01F9438         72
# 15EDFB01-20F8-451D-968C-3D76DA48FA5D       8675
# 2023D051-1530-43A4-B039-7225D3A210D9       8733
# 27F0C275-12AC-452D-BD2D-FB2D6D6977CE     210621
# 2BB774CA-42B6-4958-AEAD-BE99DBE606CC     139473
# 34F59AF1-257C-4CEA-BEB0-67911D3F179D    1634783
# 3B4192CC-761D-45BA-A325-8D023FDC6D3A      66136
# 440D767E-C2C6-4344-87E0-4FDC517401A9       4828
# 485A81C2-65C2-4725-90A9-6AF52734DD23       2952
# 487B7C30-6569-4857-8188-3DC4F2DC266D    1590057
# 4903AA7A-ACE3-4C66-AD62-3FDBDD13CBF5     430271
# 4A74F755-039A-4777-834D-E9D7033E9142    2057113
# 4C94CE12-1188-4B0C-9122-F2BDE5CB697A       4237
# 4F8F5521-B308-4503-89B9-9482D8B24351     123884
# 4FC32C34-7C03-4291-9325-6CA7055E7777      26751
# 4FF291F2-92A7-49AF-A40E-EB76D8F18F58      32424
# 54FAF654-1B94-4860-B113-9AE4CE8F1CFD      35082
# ...

# %%
# Plot grafico de vendas por cliente
vendas_por_cliente = df_vendas.groupby(['cli_codigo'])['N_Boletos'].sum()
plt.figure(figsize=(25, 12))
vendas_por_cliente.plot(kind='bar')
plt.title('Vendas por Cliente')
plt.xlabel('Cliente')
plt.ylabel('Vendas')
# Out:
# Text(0, 0.5, 'Vendas')

# %%
df_vendas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2116527 entries, 0 to 1495
# Data columns (total 9 columns):
#  #   Column        Dtype
# ---  ------        -----
#  0   Data          object
#  1   Funcionario   object
#  2   Unidade       object
#  3   N_Boletos     int64
#  4   N_Produtos    float64
#  5   Vlr_Bruto     float64
#  6   Vlr_Desconto  float64
#  7   Vlr_Liquido   float64
#  8   cli_codigo    object
# dtypes: float64(4), int64(1), object(4)
# memory usage: 161.5+ MB

# %%
df_vendas.describe()
# Out:
#           N_Boletos    N_Produtos     Vlr_Bruto  Vlr_Desconto   Vlr_Liquido
# count  2.116527e+06  2.116364e+06  2.116527e+06  2.116527e+06  2.116527e+06
# mean   1.119827e+01  5.039832e+02  4.142203e+03  6.391239e+02  3.471043e+03
# std    2.270883e+01  1.541019e+04  4.516876e+04  6.004310e+03  4.260790e+04
# min    0.000000e+00 -2.016000e+05 -4.519145e+05 -4.273245e+05 -4.519145e+05
# 25%    2.000000e+00  4.000000e+00  6.580000e+02  0.000000e+00  5.450000e+02
# 50%    4.000000e+00  1.200000e+01  1.961860e+03  3.696000e+01  1.671000e+03
# 75%    1.200000e+01  5.100000e+01  4.371000e+03  4.700000e+02  3.578140e+03
# max    2.235000e+03  2.375249e+06  9.041137e+06  1.909100e+06  8.077263e+06
